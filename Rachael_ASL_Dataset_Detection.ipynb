# %%
#only need to run once everytime you start colab
# !unzip asl_dataset.zip -d asl_dataset
# Out:
# Archive:  asl_dataset.zip
# replace asl_dataset/asl_dataset/a/hand1_a_bot_seg_1_cropped.jpeg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
from torch.utils.data import Dataset

# Fix: custom wrapper to apply different transforms to train vs val
class TransformSubset(Dataset):
    def __init__(self, subset, transform):
        self.subset = subset
        self.transform = transform

    def __getitem__(self, index):
        x, y = self.subset[index]
        return self.transform(x), y

    def __len__(self):
        return len(self.subset)

train_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((64, 64)),
    transforms.RandomRotation(15),  # removed RandomHorizontalFlip
    transforms.ColorJitter(brightness=0.3, contrast=0.3),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

val_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((64, 64)),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# Load dataset WITHOUT any transform first
data_path = 'asl_dataset/asl_dataset'
#dataset = datasets.ImageFolder(root=data_path, transform=None)
dataset = datasets.ImageFolder(root=data_path)

print("Classes found:", dataset.classes)
print("Total images:", len(dataset))

# 80/20 split
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_subset, val_subset = random_split(dataset, [train_size, val_size])

# Apply separate transforms to each subset
train_dataset = TransformSubset(train_subset, train_transform)
val_dataset = TransformSubset(val_subset, val_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

print(f"Training samples: {train_size}")
print(f"Validation samples: {val_size}")
# Out:
# Classes found: ['a', 'b', 'c', 'd', 'e']
# Total images: 350
# Training samples: 280
# Validation samples: 70

# %%
import torch.nn as nn
class ASLNet(nn.Module):
    def __init__(self):
        super(ASLNet, self).__init__()

        self.conv_layers = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
        )

        self.fc_layers = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 5)
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = self.fc_layers(x)
        return x

model = ASLNet()
print(f"\nTotal parameters: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# Total parameters: 32,261

# %%
import torch.optim as optim
from sklearn.metrics import f1_score

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

epochs = 60

for epoch in range(epochs):
    model.train()
    train_correct = 0
    train_total = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_acc = 100 * train_correct / train_total

    model.eval()
    val_correct = 0
    val_total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    val_acc = 100 * val_correct / val_total
    f1 = f1_score(all_labels, all_preds, average='macro')

    print(f"Epoch {epoch+1}/{epochs} | Train Acc: {train_acc:.1f}% | Val Acc: {val_acc:.1f}% | F1: {f1:.4f}")
# Out:
# Epoch 1/60 | Train Acc: 20.0% | Val Acc: 14.3% | F1: 0.0506
# Epoch 2/60 | Train Acc: 26.8% | Val Acc: 22.9% | F1: 0.1469
# Epoch 3/60 | Train Acc: 29.3% | Val Acc: 22.9% | F1: 0.1723
# Epoch 4/60 | Train Acc: 29.6% | Val Acc: 22.9% | F1: 0.1679
# Epoch 5/60 | Train Acc: 28.9% | Val Acc: 25.7% | F1: 0.1600
# Epoch 6/60 | Train Acc: 33.6% | Val Acc: 22.9% | F1: 0.1723
# Epoch 7/60 | Train Acc: 28.2% | Val Acc: 41.4% | F1: 0.3820
# Epoch 8/60 | Train Acc: 33.2% | Val Acc: 27.1% | F1: 0.1727
# Epoch 9/60 | Train Acc: 33.6% | Val Acc: 38.6% | F1: 0.3150
# Epoch 10/60 | Train Acc: 37.9% | Val Acc: 21.4% | F1: 0.1637
# Epoch 11/60 | Train Acc: 37.5% | Val Acc: 51.4% | F1: 0.4603
# Epoch 12/60 | Train Acc: 43.2% | Val Acc: 47.1% | F1: 0.4533
# Epoch 13/60 | Train Acc: 46.1% | Val Acc: 37.1% | F1: 0.2891
# Epoch 14/60 | Train Acc: 43.2% | Val Acc: 62.9% | F1: 0.6246
# Epoch 15/60 | Train Acc: 42.9% | Val Acc: 62.9% | F1: 0.6179
# Epoch 16/60 | Train Acc: 47.5% | Val Acc: 44.3% | F1: 0.4185
# Epoch 17/60 | Train Acc: 47.1% | Val Acc: 48.6% | F1: 0.4784
# Epoch 18/60 | Train Acc: 51.1% | Val Acc: 60.0% | F1: 0.6016
# Epoch 19/60 | Train Acc: 44.3% | Val Acc: 57.1% | F1: 0.5620
# Epoch 20/60 | Train Acc: 50.4% | Val Acc: 41.4% | F1: 0.3752
# Epoch 21/60 | Train Acc: 51.1% | Val Acc: 40.0% | F1: 0.3519
# Epoch 22/60 | Train Acc: 46.1% | Val Acc: 45.7% | F1: 0.4498
# Epoch 23/60 | Train Acc: 44.6% | Val Acc: 58.6% | F1: 0.5450
# Epoch 24/60 | Train Acc: 49.3% | Val Acc: 70.0% | F1: 0.6960
# Epoch 25/60 | Train Acc: 48.9% | Val Acc: 64.3% | F1: 0.6438
# Epoch 26/60 | Train Acc: 54.6% | Val Acc: 57.1% | F1: 0.5609
# Epoch 27/60 | Train Acc: 55.7% | Val Acc: 65.7% | F1: 0.6252
# Epoch 28/60 | Train Acc: 61.4% | Val Acc: 65.7% | F1: 0.6476
# Epoch 29/60 | Train Acc: 55.7% | Val Acc: 47.1% | F1: 0.4563
# Epoch 30/60 | Train Acc: 54.6% | Val Acc: 64.3% | F1: 0.6532
# Epoch 31/60 | Train Acc: 54.6% | Val Acc: 70.0% | F1: 0.6847
# Epoch 32/60 | Train Acc: 60.4% | Val Acc: 77.1% | F1: 0.7745
# Epoch 33/60 | Train Acc: 62.5% | Val Acc: 80.0% | F1: 0.7938
# Epoch 34/60 | Train Acc: 64.3% | Val Acc: 71.4% | F1: 0.7221
# Epoch 35/60 | Train Acc: 66.4% | Val Acc: 74.3% | F1: 0.7444
# Epoch 36/60 | Train Acc: 70.0% | Val Acc: 71.4% | F1: 0.7203
# Epoch 37/60 | Train Acc: 66.8% | Val Acc: 75.7% | F1: 0.7532
# Epoch 38/60 | Train Acc: 68.6% | Val Acc: 80.0% | F1: 0.7887
# Epoch 39/60 | Train Acc: 68.6% | Val Acc: 87.1% | F1: 0.8673
# Epoch 40/60 | Train Acc: 72.1% | Val Acc: 80.0% | F1: 0.7852
# Epoch 41/60 | Train Acc: 76.1% | Val Acc: 90.0% | F1: 0.8997
# Epoch 42/60 | Train Acc: 76.1% | Val Acc: 87.1% | F1: 0.8738
# Epoch 43/60 | Train Acc: 75.0% | Val Acc: 82.9% | F1: 0.8301
# Epoch 44/60 | Train Acc: 83.6% | Val Acc: 92.9% | F1: 0.9307
# Epoch 45/60 | Train Acc: 78.6% | Val Acc: 94.3% | F1: 0.9480
# Epoch 46/60 | Train Acc: 80.0% | Val Acc: 95.7% | F1: 0.9567
# Epoch 47/60 | Train Acc: 82.9% | Val Acc: 97.1% | F1: 0.9722
# Epoch 48/60 | Train Acc: 85.4% | Val Acc: 92.9% | F1: 0.9355
# Epoch 49/60 | Train Acc: 84.3% | Val Acc: 98.6% | F1: 0.9882
# Epoch 50/60 | Train Acc: 88.9% | Val Acc: 98.6% | F1: 0.9882
# Epoch 51/60 | Train Acc: 88.9% | Val Acc: 97.1% | F1: 0.9761
# Epoch 52/60 | Train Acc: 88.2% | Val Acc: 98.6% | F1: 0.9882
# Epoch 53/60 | Train Acc: 90.7% | Val Acc: 95.7% | F1: 0.9640
# Epoch 54/60 | Train Acc: 90.4% | Val Acc: 100.0% | F1: 1.0000
# Epoch 55/60 | Train Acc: 91.8% | Val Acc: 100.0% | F1: 1.0000
# Epoch 56/60 | Train Acc: 93.6% | Val Acc: 98.6% | F1: 0.9882
# Epoch 57/60 | Train Acc: 91.8% | Val Acc: 100.0% | F1: 1.0000
# Epoch 58/60 | Train Acc: 92.9% | Val Acc: 100.0% | F1: 1.0000
# Epoch 59/60 | Train Acc: 91.4% | Val Acc: 100.0% | F1: 1.0000
# Epoch 60/60 | Train Acc: 95.0% | Val Acc: 100.0% | F1: 1.0000
